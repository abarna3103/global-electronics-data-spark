# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Customers.csv",encoding='cp1252')

for col in ['CustomerKey','Zip Code']:
    df[col]=pd.to_numeric(df[col],errors='coerce')
df.isnull().sum()
df.fillna(method='ffill',inplace=True)
df.isnull().sum()
df['Birthday'] = pd.to_datetime(df['Birthday'])
df['Birthday'] = df['Birthday'].dt.strftime('%d-%m-%Y')
Output_path = r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Customers.csv"
df.to_csv(Output_path, index=False)
# Out:
# C:\Users\MP KUMAR\AppData\Local\Temp\ipykernel_9972\1316946272.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  float64
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df1=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Products.csv")
df1
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
df1.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
df1['Unit Cost USD'] = df1['Unit Cost USD'].replace({'\$': '', ',': ''}, regex=True)
df1['Unit Cost USD'] = pd.to_numeric(df1['Unit Cost USD'])
df1['Unit Price USD'] = df1['Unit Price USD'].replace({'\$': '', ',': ''}, regex=True)
df1['Unit Price USD'] = pd.to_numeric(df1['Unit Price USD'])
Output_path = r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Products.csv"
df1.to_csv(Output_path, index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\MP KUMAR\AppData\Local\Temp\ipykernel_9972\3471390793.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df1['Unit Cost USD'] = df1['Unit Cost USD'].replace({'\$': '', ',': ''}, regex=True)
# C:\Users\MP KUMAR\AppData\Local\Temp\ipykernel_9972\3471390793.py:3: SyntaxWarning: invalid escape sequence '\$'
#   df1['Unit Price USD'] = df1['Unit Price USD'].replace({'\$': '', ',': ''}, regex=True)

# %%
df3=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Stores.csv")
df3
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df3.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
df3.fillna(method='ffill',inplace=True)
# Out:
# C:\Users\MP KUMAR\AppData\Local\Temp\ipykernel_9972\1024756271.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3.fillna(method='ffill',inplace=True)

# %%
df3.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
df3['Open Date'] = pd.to_datetime(df3['Open Date'])
df3['Open Date'] = df3['Open Date'].dt.strftime('%d-%m-%Y')

# %%
Output_path = r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Stores.csv"
df3.to_csv(Output_path, index=False)

# %%
df4=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Sales.csv")
df4
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df4.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
df4.dropna(subset=['Delivery Date'], inplace=True)
df4.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
df4
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# 5            366002          3   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62878       2243029          6  2/20/2021     2/27/2021       887764
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 1             0        1048         2           USD
# ...

# %%
df4['Order Date']=pd.to_datetime(df4['Order Date'])
df4['Order Date'] = df4['Order Date'].dt.strftime('%d-%m-%Y')

# %%
df4
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 1            366001          1  01-01-2016     1/13/2016      1269051
# 2            366001          2  01-01-2016     1/13/2016      1269051
# 3            366002          1  01-01-2016     1/12/2016       266019
# 4            366002          2  01-01-2016     1/12/2016       266019
# 5            366002          3  01-01-2016     1/12/2016       266019
# ...             ...        ...         ...           ...          ...
# 62878       2243029          6  20-02-2021     2/27/2021       887764
# 62880       2243031          1  20-02-2021     2/24/2021       511229
# 62881       2243032          1  20-02-2021     2/23/2021       331277
# 62882       2243032          2  20-02-2021     2/23/2021       331277
# 62883       2243032          3  20-02-2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 1             0        1048         2           USD
# ...

# %%
df4['Delivery Date']=pd.to_datetime(df4['Delivery Date'])
df4['Delivery Date'] = df4['Delivery Date'].dt.strftime('%d-%m-%Y')
df4
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 1            366001          1  01-01-2016    13-01-2016      1269051
# 2            366001          2  01-01-2016    13-01-2016      1269051
# 3            366002          1  01-01-2016    12-01-2016       266019
# 4            366002          2  01-01-2016    12-01-2016       266019
# 5            366002          3  01-01-2016    12-01-2016       266019
# ...             ...        ...         ...           ...          ...
# 62878       2243029          6  20-02-2021    27-02-2021       887764
# 62880       2243031          1  20-02-2021    24-02-2021       511229
# 62881       2243032          1  20-02-2021    23-02-2021       331277
# 62882       2243032          2  20-02-2021    23-02-2021       331277
# 62883       2243032          3  20-02-2021    23-02-2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 1             0        1048         2           USD
# ...

# %%
df4 = df4[df4['Delivery Date'] >= df4['Order Date']]
df4
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 1            366001          1  01-01-2016    13-01-2016      1269051
# 2            366001          2  01-01-2016    13-01-2016      1269051
# 3            366002          1  01-01-2016    12-01-2016       266019
# 4            366002          2  01-01-2016    12-01-2016       266019
# 5            366002          3  01-01-2016    12-01-2016       266019
# ...             ...        ...         ...           ...          ...
# 62878       2243029          6  20-02-2021    27-02-2021       887764
# 62880       2243031          1  20-02-2021    24-02-2021       511229
# 62881       2243032          1  20-02-2021    23-02-2021       331277
# 62882       2243032          2  20-02-2021    23-02-2021       331277
# 62883       2243032          3  20-02-2021    23-02-2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 1             0        1048         2           USD
# ...

# %%
Output_path = r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Sales.csv"
df4.to_csv(Output_path, index=False)

# %%
df5=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Exchange_Rates.csv")
df5
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df5['Date']=pd.to_datetime(df5['Date'])
df5['Date'] = df5['Date'].dt.strftime('%d-%m-%Y')
df5
# Out:
#              Date Currency  Exchange
# 0      01-01-2015      USD    1.0000
# 1      01-01-2015      CAD    1.1583
# 2      01-01-2015      AUD    1.2214
# 3      01-01-2015      EUR    0.8237
# 4      01-01-2015      GBP    0.6415
# ...           ...      ...       ...
# 11210  20-02-2021      USD    1.0000
# 11211  20-02-2021      CAD    1.2610
# 11212  20-02-2021      AUD    1.2723
# 11213  20-02-2021      EUR    0.8238
# 11214  20-02-2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df5.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
Output_path = r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Exchange_Rates.csv"
df5.to_csv(Output_path, index=False)

# %%
df6=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Data_Dictionary.csv")
df6
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...

# %%
#merging one by one
df=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Customers.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  float64
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df1=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Products.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
df2=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Stores.csv")

# %%
df3=pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Sales.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11207 entries, 0 to 11206
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   11207 non-null  int64
#  1   Line Item      11207 non-null  int64
#  2   Order Date     11207 non-null  object
#  3   Delivery Date  11207 non-null  object
#  4   CustomerKey    11207 non-null  int64
#  5   StoreKey       11207 non-null  int64
#  6   ProductKey     11207 non-null  int64
#  7   Quantity       11207 non-null  int64
#  8   Currency Code  11207 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 788.1+ KB

# %%
merge_cus_sales = pd.merge(df,df3,on='CustomerKey',how='inner')
merge_cus_sales
# Out:
#        CustomerKey  Gender              Name                City State Code  \
# 0              301  Female     Lilly Harding      WANDEARAH EAST         SA
# 1              325  Female      Madison Hull          MOUNT BUDD         WA
# 2              325  Female      Madison Hull          MOUNT BUDD         WA
# 3              325  Female      Madison Hull          MOUNT BUDD         WA
# 4              325  Female      Madison Hull          MOUNT BUDD         WA
# ...            ...     ...               ...                 ...        ...
# 11202      2098223  Female  Hansine Davidsen         Westerville         OH
# 11203      2098223  Female  Hansine Davidsen         Westerville         OH
# 11204      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 11205      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 11206      2098404  Female    Lenka Cadilová  Pump Station Three         AK
#
# ...

# %%
merge_cus_sales_with_product=pd.merge(merge_cus_sales,df1,on='ProductKey',how='inner')
merge_cus_sales_with_product
# Out:
#        CustomerKey  Gender              Name                City State Code  \
# 0              301  Female     Lilly Harding      WANDEARAH EAST         SA
# 1              325  Female      Madison Hull          MOUNT BUDD         WA
# 2              325  Female      Madison Hull          MOUNT BUDD         WA
# 3              325  Female      Madison Hull          MOUNT BUDD         WA
# 4              325  Female      Madison Hull          MOUNT BUDD         WA
# ...            ...     ...               ...                 ...        ...
# 11202      2098223  Female  Hansine Davidsen         Westerville         OH
# 11203      2098223  Female  Hansine Davidsen         Westerville         OH
# 11204      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 11205      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 11206      2098404  Female    Lenka Cadilová  Pump Station Three         AK
#
# ...

# %%
merge_cus_sales_with_product.shape
# Out:
# (11207, 27)

# %%
merge_cussalesprod_with_stores=pd.merge(merge_cus_sales_with_product,df2,on='StoreKey',how='inner')
merge_cussalesprod_with_stores
# Out:
#        CustomerKey  Gender              Name                City State Code  \
# 0              301  Female     Lilly Harding      WANDEARAH EAST         SA
# 1              325  Female      Madison Hull          MOUNT BUDD         WA
# 2              325  Female      Madison Hull          MOUNT BUDD         WA
# 3              325  Female      Madison Hull          MOUNT BUDD         WA
# 4              325  Female      Madison Hull          MOUNT BUDD         WA
# ...            ...     ...               ...                 ...        ...
# 11202      2098223  Female  Hansine Davidsen         Westerville         OH
# 11203      2098223  Female  Hansine Davidsen         Westerville         OH
# 11204      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 11205      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 11206      2098404  Female    Lenka Cadilová  Pump Station Three         AK
#
# ...

# %%
df5 = pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Cleaned_Exchange_Rates.csv")
merge_cussalesprodstore_with_rate=pd.merge(merge_cussalesprod_with_stores,df5,left_on='Order Date', right_on='Date', how='inner')
merge_cussalesprodstore_with_rate
# Out:
#        CustomerKey  Gender            Name                City State Code  \
# 0              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 1              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 2              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 3              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 4              301  Female   Lilly Harding      WANDEARAH EAST         SA
# ...            ...     ...             ...                 ...        ...
# 56030      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56031      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56032      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56033      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56034      2098404  Female  Lenka Cadilová  Pump Station Three         AK
#
#                State_x  Zip Code      Country_x      Continent    Birthday  \
# ...

# %%
merge_cussalesprodstore_with_rate.drop(columns=['State_y', 'Country_y', 'Date'], inplace=True)

# %%
merge_cussalesprodstore_with_rate.columns
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State_x',
#        'Zip Code', 'Country_x', 'Continent', 'Birthday', 'Order Number',
#        'Line Item', 'Order Date', 'Delivery Date', 'StoreKey', 'ProductKey',
#        'Quantity', 'Currency Code', 'Product Name', 'Brand', 'Color',
#        'Unit Cost USD', 'Unit Price USD', 'SubcategoryKey', 'Subcategory',
#        'CategoryKey', 'Category', 'Square Meters', 'Open Date', 'Currency',
#        'Exchange'],
#       dtype='object')

# %%
merge_cussalesprodstore_with_rate.rename(columns={'State_x': 'State', 'Country_x': 'Country'}, inplace=True)

# %%
merge_cussalesprodstore_with_rate.columns
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State',
#        'Zip Code', 'Country', 'Continent', 'Birthday', 'Order Number',
#        'Line Item', 'Order Date', 'Delivery Date', 'StoreKey', 'ProductKey',
#        'Quantity', 'Currency Code', 'Product Name', 'Brand', 'Color',
#        'Unit Cost USD', 'Unit Price USD', 'SubcategoryKey', 'Subcategory',
#        'CategoryKey', 'Category', 'Square Meters', 'Open Date', 'Currency',
#        'Exchange'],
#       dtype='object')

# %%
# Save the final dataset to a new CSV file
Output_path = r"C:\Users\MP KUMAR\Downloads\data spark project\Final_data_spark.csv"
merge_cussalesprodstore_with_rate.to_csv(Output_path, index=False)

# %%
#storing the data in SQL using mysql
# Load CSV data
import pandas as pd
from mysql import connector
df = pd.read_csv(r"C:\Users\MP KUMAR\Downloads\data spark project\Final_data_spark.csv")

from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:123456789@127.0.0.1:3306/DataSpark')
df.to_sql('sample_database', con=engine, if_exists='replace', index=False)
print("Data inserted successfuly in database")
# Out:
# Data inserted successfuly in database

# %%
query = "SELECT * FROM sample_database LIMIT 10;"  
df_from_db = pd.read_sql(query, con=engine)

# Display the data
print(df_from_db)
# Out:
#    CustomerKey  Gender           Name            City State Code  \
# 0          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 1          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 2          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 3          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 4          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 5          325  Female   Madison Hull      MOUNT BUDD         WA
# 6          325  Female   Madison Hull      MOUNT BUDD         WA
# 7          325  Female   Madison Hull      MOUNT BUDD         WA
# 8          325  Female   Madison Hull      MOUNT BUDD         WA
# 9          325  Female   Madison Hull      MOUNT BUDD         WA
#
#                State  Zip Code    Country  Continent    Birthday  ...  \
# 0    South Australia    5523.0  Australia  Australia  03-07-1939  ...
# 1    South Australia    5523.0  Australia  Australia  03-07-1939  ...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        CustomerKey  Gender            Name                City State Code  \
# 0              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 1              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 2              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 3              301  Female   Lilly Harding      WANDEARAH EAST         SA
# 4              301  Female   Lilly Harding      WANDEARAH EAST         SA
# ...            ...     ...             ...                 ...        ...
# 56030      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56031      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56032      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56033      2098404  Female  Lenka Cadilová  Pump Station Three         AK
# 56034      2098404  Female  Lenka Cadilová  Pump Station Three         AK
#
# ...

# %%
query = "SELECT Gender, Continent, COUNT(CustomerKey) AS CustomerCount FROM sample_database GROUP BY Gender, Continent ORDER BY CustomerCount DESC;"
df_from_db = pd.read_sql(query, con=engine)

# Display the data
print(df_from_db)
# Out:
#    Gender      Continent  CustomerCount
# 0    Male  North America          18100
# 1  Female  North America          17685
# 2    Male         Europe           8745
# 3  Female         Europe           8525
# 4  Female      Australia           1600
# 5    Male      Australia           1380

# %%
query = "SELECT Country, CASE WHEN YEAR(CURDATE()) - YEAR(Birthday) < 25 THEN 'Under 25' WHEN YEAR(CURDATE()) - YEAR(Birthday) BETWEEN 25 AND 35 THEN '25-35' WHEN YEAR(CURDATE()) - YEAR(Birthday) BETWEEN 36 AND 50 THEN '36-50' ELSE 'Above 50' END AS AgeGroup,COUNT(CustomerKey) AS CustomerCount FROM sample_database WHERE Birthday IS NOT NULL GROUP BY Country, AgeGroup ORDER BY CustomerCount DESC;"
df_from_db = pd.read_sql(query, con=engine)

# Display the data
print(df_from_db)
# Out:
#           Country  AgeGroup  CustomerCount
# 0   United States  Above 50          30605
# 1  United Kingdom  Above 50           6500
# 2         Germany  Above 50           5445
# 3          Canada  Above 50           5180
# 4       Australia  Above 50           2980
# 5           Italy  Above 50           2020
# 6     Netherlands  Above 50           1855
# 7          France  Above 50           1450

# %%
query="SELECT City, Country,COUNT(CustomerKey) AS CustomerCount FROM sample_database GROUP BY City, Country ORDER BY CustomerCount DESC LIMIT 5;"
df_from_db= pd.read_sql(query, con=engine)
#Display the data
# Display the data
print(df_from_db)
# Out:
#           City        Country  CustomerCount
# 0      Toronto         Canada            670
# 1  Los Angeles  United States            615
# 2     New York  United States            580
# 3     Montreal         Canada            355
# 4      Calgary         Canada            345

# %%
query="SELECT Subcategory, SUM(Quantity) AS TotalPurchased FROM sample_database WHERE Gender = 'Female' GROUP BY Subcategory ORDER BY TotalPurchased DESC LIMIT 3;"
df_from_db=pd.read_sql(query,con=engine)
print(df_from_db)
# Out:
#             Subcategory  TotalPurchased
# 0             Movie DVD         13160.0
# 1              Desktops          9380.0
# 2  Bluetooth Headphones          6090.0

# %%
query="SELECT Gender, Continent, COUNT(CustomerKey) AS CustomerCount FROM data_spark GROUP BY Gender, Continent ORDER BY CustomerCount DESC;"
df_from_db=pd.read_sql(query,con=engine)
print(df_from_db)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 query="SELECT DATE_FORMAT('Order_Date', '%Y-%m') AS month,SUM('Quantity' * 'Unit Price USD') AS total_sales FROM sample_database GROUP BY month ORDER BY month;"
# ----> 2 df_from_db=pd.read_sql(query,con=engine)
#       3 print(df_from_db)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)
#     731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
# ...

# %%
query="SELECT 'Product Name',SUM('Quantity') AS total_quantity_sold,SUM(`Quantity` * `Unit Price USD`) AS total_revenue FROM sample_database GROUP BY `Product Name` ORDER BY total_quantity_sold DESC;"
